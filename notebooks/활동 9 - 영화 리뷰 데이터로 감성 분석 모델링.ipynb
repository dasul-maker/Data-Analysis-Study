# %%
import pandas as pd
nsmc_train_df = pd.read_csv('/content/drive/MyDrive/data/영화리뷰/ratings_train.txt', encoding = 'utf8', sep = '\t', engine = 'python')
nsmc_train_df.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
nsmc_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        150000 non-null  int64
#  1   document  149995 non-null  object
#  2   label     150000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ MB

# %%
nsmc_train_df = nsmc_train_df[nsmc_train_df['document'].notnull()]
nsmc_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149995 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        149995 non-null  int64
#  1   document  149995 non-null  object
#  2   label     149995 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.6+ MB

# %%
nsmc_train_df['label'].value_counts()
# Out:
# label
# 0    75170
# 1    74825
# Name: count, dtype: int64

# %%
import re
nsmc_train_df['document'] = nsmc_train_df['document'].apply(lambda x : re.sub(r'[^ ㄱ-ㅣ가-힣]+', '', x))
nsmc_train_df.head()
# Out:
#          id                                           document  label
# 0   9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1   3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1

# %%
nsmc_test_df = pd.read_csv('/content/drive/MyDrive/data/영화리뷰/ratings_test.txt', encoding='utf8', sep='\t', engine='python')
nsmc_test_df.head()
# Out:
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0

# %%
nsmc_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        50000 non-null  int64
#  1   document  49997 non-null  object
#  2   label     50000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.1+ MB

# %%
#document 컬럼이 Null인 샘플 제거
nsmc_test_df = nsmc_test_df[nsmc_test_df['document'].notnull()]
nsmc_test_df['label'].value_counts()
# Out:
# label
# 1    25171
# 0    24826
# Name: count, dtype: int64

# %%
nsmc_test_df['document'] = nsmc_test_df['document'].apply(lambda x : re.sub(r'[^ ㄱ-ㅣ가-힣]+', '', x))

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.6.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (5.4.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.11/dist-packages (from konlpy) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from JPype1>=0.7.0->konlpy) (25.0)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 13.7 MB/s eta 0:00:00
# Downloading jpype1-1.6.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (496 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.6/496.6 kB 33.9 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.6.0 konlpy-0.6.0

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
def okt_tokenizer(text):
  tokens = okt.morphs(text)
  return tokens

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(tokenizer=okt_tokenizer, ngram_range=(1,2), min_df=3, max_df=0.9, token_pattern = None)
tfidf.fit(nsmc_train_df['document'])
nsmc_train_tfidf = tfidf.transform(nsmc_train_df['document'])

# %%
from sklearn.linear_model import LogisticRegression
SA_lr = LogisticRegression(random_state=0, max_iter = 500)
SA_lr.fit(nsmc_train_tfidf, nsmc_train_df['label'])
# Out:
# LogisticRegression(max_iter=500, random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
params = {'C' : [1,3,3.5,4,4.5,5]}
SA_lr_grid_cv = GridSearchCV(SA_lr, param_grid = params, cv = 3, scoring = 'accuracy', verbose = 1)
SA_lr_grid_cv.fit(nsmc_train_tfidf, nsmc_train_df['label'])
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=3, estimator=LogisticRegression(max_iter=500, random_state=0),
#              param_grid={'C': [1, 3, 3.5, 4, 4.5, 5]}, scoring='accuracy',
#              verbose=1)

# %%
print(SA_lr_grid_cv.best_params_, round(SA_lr_grid_cv.best_score_, 4))
# Out:
# {'C': 4} 0.8551

# %%
#최적 매개변수의 best 모델 저장
SA_lr_best = SA_lr_grid_cv.best_estimator_

# %%
#평가 데이터의 피처 벡터와
nsmc_test_tfidf = tfidf.transform(nsmc_test_df['document'])
test_predict = SA_lr_best.predict(nsmc_test_tfidf)
from sklearn.metrics import accuracy_score
print('감성 분석 정확도 : ', round(accuracy_score(nsmc_test_df['label'], test_predict), 3))
# Out:
# 감성 분석 정확도 :  0.858

# %%
st = input('감성 분석할 문장 입력>>')
# Out:
# 감성 분석할 문장 입력>>야호~! 집 대출금을 모두 갚았어~!

# %%
# 0) 입력 텍스트에 대한 전처리 수행
st = re.compile(r'[ㄱ-ㅣ가-힣]+').findall(st)
print(st)
st = [" ".join(st)]
print(st)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3617676465.py in <cell line: 0>()
#       1 # 0) 입력 텍스트에 대한 전처리 수행
# ----> 2 st = re.compile(r'[ㄱ-ㅣ가-힣]+').findall(st)
#       3 print(st)
#       4 st = [" ".join(st)]
#       5 print(st)
#
# NameError: name 're' is not defined

# %%
# 1) 입력 텍스트의 피처 벡터화
st_tfidf = tfidf.transform(st)

# 2) 최적 감성 분석 모델에 적용하여 감성 분석 평가
st_predict = SA_lr_best.predict(st_tfidf)

# %%
# 3) 예측값 출력하기
if st_predict == 0:
  print(st, '==> 부정 감성')
else:
  print(st, '==> 긍정 감성')
# Out:
# ['웃자 오늘은 좋은 날이 될 것 같은 예감'] ==> 긍정 감성
